# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# ### Read the Data

# %%
data = pd.read_csv('Data/Online Retail.csv')

# %%
data.head(10)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     542504     37413                                  NaN      5568
# 1     573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 2     554868     22197                 SMALL POPCORN HOLDER      4300
# 3     556231    85123A                                    ?      4000
# 4     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 5     560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 6     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 7     550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 8     560040     23343                  came coded as 20713      3100
# 9     546139     84988                                    ?      3000
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  28/01/2011 12:03       0.00         NaN  United Kingdom
# 1  27/10/2011 12:26       0.21     12901.0  United Kingdom
# 2  27/05/2011 10:52       0.72     13135.0  United Kingdom
# 3  09/06/2011 15:04       0.00         NaN  United Kingdom
# 4  22/02/2011 10:43       0.82     18087.0  United Kingdom
# 5  19/07/2011 17:04       0.06     14609.0  United Kingdom
# 6  11/01/2011 12:55       2.10     15749.0  United Kingdom
# 7  18/04/2011 13:20       2.10     15749.0  United Kingdom
# 8  14/07/2011 14:28       0.00         NaN  United Kingdom
# 9  09/03/2011 16:35       0.00         NaN  United Kingdom

# %% [markdown]
# ### Cleaning Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    99999 non-null  int64
#  1   StockCode    99999 non-null  object
#  2   Description  99772 non-null  object
#  3   Quantity     99999 non-null  int64
#  4   InvoiceDate  99999 non-null  object
#  5   UnitPrice    99999 non-null  float64
#  6   CustomerID   94764 non-null  float64
#  7   Country      99999 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
data.isnull().sum()
# Out:
# InvoiceNo         0
# StockCode         0
# Description     227
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID     5235
# Country           0
# dtype: int64

# %%
cleaned_data = data.dropna(subset=['CustomerID', 'Description'])

cleaned_data['InvoiceDate'] = pd.to_datetime(cleaned_data['InvoiceDate'])

cleaned_data['TotalPrice'] = cleaned_data['Quantity'] * cleaned_data['UnitPrice']

customer_data.to_csv('cleaned_customer_data.csv', index=False)

customer_data = cleaned_data.groupby('CustomerID').agg({
    'InvoiceNo': 'nunique',  # Number of unique transactions (orders) per customer
    'Quantity': 'sum',       # Total quantity of products purchased by each customer
    'TotalPrice': 'sum'      # Total spending by each customer
}).rename(columns={'InvoiceNo': 'TotalOrders'})

customer_data.reset_index(inplace=True)

customer_data.to_csv('cleaned_data.csv', index=False)

customer_data.head()
# Out:
# /var/folders/_b/ygjd3hwd5wj6hwcczmfy35gh0000gn/T/ipykernel_56290/3929399507.py:3: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cleaned_data['InvoiceDate'] = pd.to_datetime(cleaned_data['InvoiceDate'])
# /var/folders/_b/ygjd3hwd5wj6hwcczmfy35gh0000gn/T/ipykernel_56290/3929399507.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['InvoiceDate'] = pd.to_datetime(cleaned_data['InvoiceDate'])
# /var/folders/_b/ygjd3hwd5wj6hwcczmfy35gh0000gn/T/ipykernel_56290/3929399507.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data['TotalPrice'] = cleaned_data['Quantity'] * cleaned_data['UnitPrice']
#    CustomerID  TotalOrders  Quantity  TotalPrice
# 0     12347.0            7      1702     1989.26
# 1     12348.0            4      2332     1437.24
# 2     12349.0            1       162      158.44
# 3     12350.0            1       180      268.20
# 4     12352.0            5       216      286.56

# %% [markdown]
# ### Scaling Numerical Values

# %% [markdown]
# #### StandardScaler

# %%
# Normalize data

scaler = StandardScaler()
scaled_customer_data = scaler.fit_transform(customer_data[['TotalOrders', 'Quantity', 'TotalPrice']])

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# Applying PCA to reduce dimensions while capturing as much variance as possible
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization purposes
pca_customer_data = pca.fit_transform(scaled_customer_data)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Assign clusters back to the customer data
customer_data['Cluster'] = kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('Customer Segmentation using PCA and K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

silhouette_avg
# Out:
# 0.7905057396966444

# %% [markdown]
# #### MinMaxScaler

# %%
# Normalize data

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_customer_data = scaler.fit_transform(customer_data[['TotalOrders', 'Quantity', 'TotalPrice']])

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# Applying PCA to reduce dimensions while capturing as much variance as possible
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization purposes
pca_customer_data = pca.fit_transform(scaled_customer_data)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Assign clusters back to the customer data
customer_data['Cluster'] = kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('Customer Segmentation using PCA and K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

silhouette_avg
# Out:
# 0.7771407814839499

# %% [markdown]
# #### MaxAbsScaler

# %%
# Normalize data

scaler = MaxAbsScaler()
scaled_customer_data = scaler.fit_transform(customer_data[['TotalOrders', 'Quantity', 'TotalPrice']])

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# Applying PCA to reduce dimensions while capturing as much variance as possible
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization purposes
pca_customer_data = pca.fit_transform(scaled_customer_data)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Assign clusters back to the customer data
customer_data['Cluster'] = kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('Customer Segmentation using PCA and K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

silhouette_avg
# Out:
# 0.777066198721637

# %% [markdown]
# #### RobustScaler

# %%
# Normalize data
scaler = RobustScaler()
scaled_customer_data = scaler.fit_transform(customer_data[['TotalOrders', 'Quantity', 'TotalPrice']])

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# Applying PCA to reduce dimensions while capturing as much variance as possible
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization purposes
pca_customer_data = pca.fit_transform(scaled_customer_data)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_

kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(pca_customer_data)

# Assign clusters back to the customer data
customer_data['Cluster'] = kmeans.labels_

# Calculate mean values for each cluster to understand their characteristics
cluster_analysis = customer_data.groupby('Cluster').agg({
    'TotalOrders': 'mean',
    'Quantity': 'mean',
    'TotalPrice': 'mean'
}).rename(columns={
    'TotalOrders': 'Average Total Orders',
    'Quantity': 'Average Quantity',
    'TotalPrice': 'Average Total Price'
})

print(cluster_analysis)

cluster_names = {
    0: 'Low Spending Customers',
    1: 'High Value Customers',
    2: 'Moderate Spending Customers'
}
customer_data['Customer Segment'] = customer_data['Cluster'].map(cluster_names)

# Unique colors for clusters
colors = np.array(['red', 'green', 'blue'])

plt.figure(figsize=(10, 6))
for cluster in np.unique(customer_data['Cluster']):
    # Select only data rows where cluster is equal to the current loop cluster
    cluster_data = pca_customer_data[customer_data['Cluster'] == cluster]
    plt.scatter(cluster_data[:, 0], cluster_data[:, 1], c=colors[cluster], label=f'Cluster {cluster}: {cluster_names[cluster]}', alpha=0.5)

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='black', label='Centroids')
plt.title('Customer Segmentation with Named Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

print(silhouette_avg)

customer_data.head()

customer_data.to_csv('processed_customer_data.csv', index=False)
# Out:
#          Average Total Orders  Average Quantity  Average Total Price
# Cluster
# 0                    3.523895        626.455405           770.958183
# 1                   57.000000     110010.000000        241378.400000
# 2                   43.208333      35988.250000         51953.059583
# 0.9702806280352058

# %% [markdown]
# #### Quantile Transformer

# %%
# Normalize data

scaler = QuantileTransformer(output_distribution='uniform') # or 'normal'
scaled_customer_data = scaler.fit_transform(customer_data[['TotalOrders', 'Quantity', 'TotalPrice']])

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# Applying PCA to reduce dimensions while capturing as much variance as possible
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization purposes
pca_customer_data = pca.fit_transform(scaled_customer_data)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Assign clusters back to the customer data
customer_data['Cluster'] = kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('Customer Segmentation using PCA and K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

silhouette_avg
# Out:
# 0.49737376497307073

# %% [markdown]
# #### PowerTransformer

# %%
# Normalize data

scaler = PowerTransformer(method='yeo-johnson') # or 'box-cox'
scaled_customer_data = scaler.fit_transform(customer_data[['TotalOrders', 'Quantity', 'TotalPrice']])

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(scaled_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia (Sum of squared distances)')
plt.xticks(cluster_range)
plt.grid(True)
plt.show()

# Applying PCA to reduce dimensions while capturing as much variance as possible
pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization purposes
pca_customer_data = pca.fit_transform(scaled_customer_data)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_

kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Assign clusters back to the customer data
customer_data['Cluster'] = kmeans.labels_

# Plotting the clusters
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('Customer Segmentation using PCA and K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

silhouette_avg
# Out:
# 0.39379224115088374

# %% [markdown]
# ### Save Model

# %%
import joblib

# Save the trained models
joblib.dump(scaler, 'scaler.joblib')
joblib.dump(pca, 'pca.joblib')
joblib.dump(kmeans, 'kmeans.joblib')

# Save the cluster labels dictionary
joblib.dump(cluster_names, 'cluster_names.joblib')

print("Models and cluster names saved successfully!")
# Out:
# Models and cluster names saved successfully!

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('Online Retail.csv')

# Data cleaning
data.dropna(subset=['CustomerID', 'Description'], inplace=True)  # Removing rows with missing values

# Convert 'InvoiceDate' to datetime
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# Create a total price column
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# One-hot encode 'Description' and 'Country'
data_encoded = pd.get_dummies(data, columns=['Description', 'Country'])

# Aggregate data by CustomerID
customer_data = data_encoded.groupby('CustomerID').agg({
    'InvoiceNo': 'nunique',
    'Quantity': 'sum',
    'TotalPrice': 'sum',
    **{col: 'sum' for col in data_encoded.columns if 'Country_' in col or 'Description_' in col}
}).rename(columns={'InvoiceNo': 'TotalOrders'})

# Reset index to make CustomerID a column
customer_data.reset_index(inplace=True)
# Out:
# /var/folders/_b/ygjd3hwd5wj6hwcczmfy35gh0000gn/T/ipykernel_67981/3406875998.py:14: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
# Normalize data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(customer_data.drop('CustomerID', axis=1))

# Apply PCA to reduce dimensions
pca = PCA(n_components=500)
pca_customer_data = pca.fit_transform(scaled_features)

# Plotting the PCA result to visualize the distribution
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('PCA Result (2 Components)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()

# Variance explained by each component
pca.explained_variance_ratio_
# Out:
# array([0.05454761, 0.04001938, 0.02755061, 0.0253294 , 0.01562427,
#        0.01527537, 0.0127211 , 0.01199709, 0.01096603, 0.01030693,
#        0.00858203, 0.00765528, 0.00725645, 0.00709541, 0.00632588,
#        0.00598741, 0.00538402, 0.00514429, 0.00498386, 0.00479477,
#        0.00465381, 0.00453594, 0.00431858, 0.00403999, 0.00392663,
#        0.00382677, 0.00375474, 0.00368693, 0.00352913, 0.00351715,
#        0.00349045, 0.00342749, 0.00336863, 0.00333827, 0.00328756,
#        0.00324239, 0.00315571, 0.00311514, 0.0030934 , 0.00305592,
#        0.00298423, 0.00295261, 0.00292199, 0.0028885 , 0.00282741,
#        0.00280619, 0.00279053, 0.00275018, 0.00268506, 0.00266164,
#        0.00260304, 0.00257379, 0.00252591, 0.00251448, 0.00247337,
#        0.0024177 , 0.00237871, 0.00236195, 0.00227049, 0.00219252,
#        0.0021668 , 0.0021509 , 0.00211428, 0.00208786, 0.00207428,
#        0.00204775, 0.00200807, 0.00200452, 0.00199813, 0.00195719,
#        0.0019351 , 0.00192995, 0.00192245, 0.00189491, 0.00187459,
#        0.00186912, 0.00186034, 0.00183718, 0.00182024, 0.00180838,
customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# %%
# Assume 4 clusters is optimal based on the elbow plot
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Visualize the PCA results and clusters
plt.figure(figsize=(10, 6))
plt.scatter(pca_customer_data[:, 0], pca_customer_data[:, 1], c=kmeans.labels_, cmap='viridis', alpha=0.5)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=100, c='red', label='Centroids')
plt.title('Customer Segmentation using PCA and K-Means Clustering')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)

silhouette_avg
# Out:
# 0.9200565707449235

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Assuming 'scaled_features' contains your one-hot encoded, scaled data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(customer_data.drop('CustomerID', axis=1))

# Fit PCA without specifying the number of components
pca_full = PCA()
pca_full.fit(scaled_features)

# Plot the cumulative variance explained by the PCA components
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(pca_full.explained_variance_ratio_) + 1), pca_full.explained_variance_ratio_.cumsum(), marker='o')
plt.title('Cumulative Explained Variance by PCA Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# Decide the number of components to use based on the plot
# For example, choose a number where you see about 80-90% of the variance being explained
n_components = 50  # This is an example, adjust based on your specific data and analysis

# Now fit PCA with the selected number of components
pca = PCA(n_components=n_components)
pca_customer_data = pca.fit_transform(scaled_features)

# Continue with your clustering or other analyses using 'pca_customer_data'

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from joblib import dump, load

# Load the data
data = pd.read_csv('Online Retail.csv')

# Data cleaning
data.dropna(subset=['CustomerID', 'Description'], inplace=True)  # Removing rows with missing values

# Convert 'InvoiceDate' to datetime and create 'TotalPrice'
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# One-hot encode 'Description' and 'Country'
data_encoded = pd.get_dummies(data, columns=['Description', 'Country'])

# Aggregate data by CustomerID
customer_data = data_encoded.groupby('CustomerID').agg({
    'InvoiceNo': 'nunique',
    'Quantity': 'sum',
    'TotalPrice': 'sum'
}).rename(columns={'InvoiceNo': 'TotalOrders'})

# Reset index to make CustomerID a column
customer_data.reset_index(inplace=True)

# Normalize data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(customer_data.drop(['CustomerID'], axis=1))

# Save the scaler to disk
dump(scaler, 'scaler.joblib')

# Determine the appropriate number of PCA components
n_samples, n_features = scaled_features.shape
n_components = min(n_samples, n_features) - 1  # Choose a safe number of components

# Apply PCA to reduce dimensions
pca = PCA(n_components=n_components)
pca_customer_data = pca.fit_transform(scaled_features)

# Save the PCA model to disk
dump(pca, 'pca.joblib')

# Determine the optimal number of clusters using the elbow method
inertia = []
cluster_range = range(1, 11)
for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(pca_customer_data)
    inertia.append(kmeans.inertia_)

# Plotting the elbow graph
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()

# Assuming 4 clusters is optimal based on the elbow plot
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(pca_customer_data)

# Save the KMeans model to disk
dump(kmeans, 'kmeans.joblib')

# Calculate the silhouette score for the K-means clustering
silhouette_avg = silhouette_score(pca_customer_data, kmeans.labels_)
print(f"Silhouette Score: {silhouette_avg:.2f}")

# Load models from disk (for new session or deployment)
scaler = load('scaler.joblib')
pca = load('pca.joblib')
kmeans = load('kmeans.joblib')

# Sample new data row and prepare it similarly
new_data = pd.DataFrame({
    'CustomerID': [12345],
    'Description': ['new_product_description'],
    'Country': ['United Kingdom'],
    'Quantity': [10],
    'UnitPrice': [15.0]
})

new_data['TotalPrice'] = new_data['Quantity'] * new_data['UnitPrice']
new_data_encoded = pd.get_dummies(new_data, columns=['Description', 'Country'])
new_data_encoded = new_data_encoded.reindex(columns=customer_data.columns.drop('CustomerID'), fill_value=0)
scaled_new_data = scaler.transform(new_data_encoded)

new_pca_data = pca.transform(scaled_new_data)
predicted_cluster = kmeans.predict(new_pca_data)
print(f"The new data row belongs to cluster: {predicted_cluster[0]}")
# Out:
# /var/folders/_b/ygjd3hwd5wj6hwcczmfy35gh0000gn/T/ipykernel_67981/578212290.py:16: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
# Silhouette Score: 0.79
# The new data row belongs to cluster: 0
